# %% [markdown]
# <a href="https://colab.research.google.com/github/CHENNURUHARISH/PLANT-LEAF-DISEASE-DETECTION/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
unnmlkmk
gjktnkd
# Out:
#   File "<ipython-input-2-3691d257fbf5>", line 1
#     gh repo clone CHENNURUHARISH/PLANT-LEAF-DISEASE-DETECTION
#        ^
# SyntaxError: invalid syntax
