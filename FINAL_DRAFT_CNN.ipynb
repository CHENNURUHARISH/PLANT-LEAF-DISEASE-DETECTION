# %% [markdown]
# <a href="https://colab.research.google.com/github/CHENNURUHARISH/PLANT-LEAF-DISEASE-DETECTION/blob/main/FINAL_DRAFT_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from tensorflow.keras.models import Sequential

import os

# Data Augmentation & Normalization

data_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal"),  # Flip images randomly
    RandomRotation(0.2),       # Rotate images randomly
    RandomZoom(0.2),           # Zoom randomly
    # RandomBrightness(0.2),      # Randomly adjust brightness by 20%
    # RandomContrast(0.2),        # Randomly adjust contrast by 20%


])

normalization_layer = Rescaling(1./255)  # Normalize pixels to range [0,1]

# Load training dataset from directory
train_dataset = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/train",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True
)

# Load validation dataset from directory
valid_dataset = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/val",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True
)

# Store class names before applying the map function
class_names = train_dataset.class_names

# Apply data augmentation & normalization to the training dataset
train_dataset = train_dataset.map(lambda x, y: (data_augmentation(normalization_layer(x)), y))
valid_dataset = valid_dataset.map(lambda x, y: (normalization_layer(x), y))


# Now you can print the class names
print("Training Set Classes:", class_names)

# Define CNN model
cnn = Sequential()
cnn.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=[128, 128, 3]))
cnn.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(MaxPool2D(pool_size=2, strides=2))

cnn.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
cnn.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
cnn.add(MaxPool2D(pool_size=2, strides=2))

cnn.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
cnn.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
cnn.add(MaxPool2D(pool_size=2, strides=2))

cnn.add(Conv2D(filters=256, kernel_size=3, padding='same', activation='relu'))
cnn.add(Conv2D(filters=256, kernel_size=3, activation='relu'))
cnn.add(MaxPool2D(pool_size=2, strides=2))

cnn.add(Conv2D(filters=512, kernel_size=3, padding='same', activation='relu'))
cnn.add(Conv2D(filters=512, kernel_size=3, activation='relu'))
cnn.add(MaxPool2D(pool_size=2, strides=2))

cnn.add(Dropout(0.3))
cnn.add(Flatten())
cnn.add(Dense(units=1020, activation='relu'))
cnn.add(Dropout(0.4))  # To avoid overfitting

# Output Layer
cnn.add(Dense(units=37, activation='softmax'))

# Compile the model
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# Train the model
training_history = cnn.fit(train_dataset, validation_data=valid_dataset, epochs=40)

# Evaluate the model on training set
train_loss, train_acc = cnn.evaluate(train_dataset)
print('Training accuracy:', train_acc)
print('Training Loss:', train_loss)

# Evaluate the model on validation set
val_loss, val_acc = cnn.evaluate(valid_dataset)
print('Validation accuracy:', val_acc)
print('Validation Loss:', val_loss)

# Save the trained model
cnn.save('trained_plant_disease_model.keras')

# Plot accuracy results
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.plot(epochs, training_history.history['accuracy'], color='red', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='blue', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Visualization of Accuracy Result')
plt.legend()
plt.show()

# Plot Loss Curve
plt.figure(figsize=(8, 6))
plt.plot(epochs, training_history.history['loss'], 'red', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], 'blue', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Load test dataset
test_set = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/val",
    labels="inferred",
    label_mode="categorical",
    batch_size=1,
    image_size=(128, 128),
    shuffle=False
)

# Get class names
class_names = test_set.class_names
print(class_names)

# Make predictions
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1)

# Get true labels
true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1)
# Out:
# Found 3815 files belonging to 37 classes.
# Found 3770 files belonging to 37 classes.
# Training Set Classes: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']
# Epoch 1/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 29s 196ms/step - accuracy: 0.0262 - loss: 3.6109 - val_accuracy: 0.0289 - val_loss: 3.6137
# Epoch 2/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - accuracy: 0.0332 - loss: 3.6033 - val_accuracy: 0.0260 - val_loss: 3.6088
# Epoch 3/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - accuracy: 0.0484 - loss: 3.4748 - val_accuracy: 0.0538 - val_loss: 3.4336
# Epoch 4/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 163ms/step - accuracy: 0.0648 - loss: 3.2917 - val_accuracy: 0.1021 - val_loss: 3.1799
# Epoch 5/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 162ms/step - accuracy: 0.0955 - loss: 3.1281 - val_accuracy: 0.1467 - val_loss: 2.8969
# Epoch 6/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.1538 - loss: 2.8058 - val_accuracy: 0.2302 - val_loss: 2.6408
# Epoch 7/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 176ms/step - accuracy: 0.2090 - loss: 2.5655 - val_accuracy: 0.2782 - val_loss: 2.4060
# Epoch 8/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.2545 - loss: 2.3568 - val_accuracy: 0.3032 - val_loss: 2.3211
# Epoch 9/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - accuracy: 0.3157 - loss: 2.2018 - val_accuracy: 0.3326 - val_loss: 2.2098
# Epoch 10/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.3601 - loss: 2.0492 - val_accuracy: 0.3780 - val_loss: 2.0289
# Epoch 11/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.4022 - loss: 1.9231 - val_accuracy: 0.4308 - val_loss: 1.7982
# Epoch 12/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - accuracy: 0.4243 - loss: 1.8207 - val_accuracy: 0.4218 - val_loss: 1.8729
# Epoch 13/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.4457 - loss: 1.7874 - val_accuracy: 0.4931 - val_loss: 1.6613
# Epoch 14/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.4778 - loss: 1.6681 - val_accuracy: 0.5324 - val_loss: 1.5029
# Epoch 15/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.5006 - loss: 1.5629 - val_accuracy: 0.5316 - val_loss: 1.5233
# Epoch 16/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - accuracy: 0.5347 - loss: 1.4712 - val_accuracy: 0.5621 - val_loss: 1.5185
# Epoch 17/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.5487 - loss: 1.4391 - val_accuracy: 0.5899 - val_loss: 1.3724
# Epoch 18/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.5459 - loss: 1.4042 - val_accuracy: 0.5764 - val_loss: 1.4303
# Epoch 19/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 161ms/step - accuracy: 0.5868 - loss: 1.3065 - val_accuracy: 0.5851 - val_loss: 1.4227
# Epoch 20/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 164ms/step - accuracy: 0.5981 - loss: 1.2469 - val_accuracy: 0.5997 - val_loss: 1.3271
# Epoch 21/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 19s 161ms/step - accuracy: 0.6195 - loss: 1.1826 - val_accuracy: 0.6162 - val_loss: 1.2242
# Epoch 22/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.6403 - loss: 1.1074 - val_accuracy: 0.6308 - val_loss: 1.1708
# Epoch 23/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 162ms/step - accuracy: 0.6510 - loss: 1.0996 - val_accuracy: 0.6249 - val_loss: 1.2370
# Epoch 24/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - accuracy: 0.6518 - loss: 1.0885 - val_accuracy: 0.6618 - val_loss: 1.1159
# Epoch 25/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.6664 - loss: 1.0140 - val_accuracy: 0.6992 - val_loss: 0.9816
# Epoch 26/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.6853 - loss: 0.9926 - val_accuracy: 0.6714 - val_loss: 1.0667
# Epoch 27/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - accuracy: 0.6991 - loss: 0.9390 - val_accuracy: 0.6873 - val_loss: 1.0390
# Epoch 28/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.7187 - loss: 0.8775 - val_accuracy: 0.6830 - val_loss: 1.0031
# Epoch 29/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.7218 - loss: 0.8215 - val_accuracy: 0.7297 - val_loss: 0.9056
# Epoch 30/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 166ms/step - accuracy: 0.7306 - loss: 0.8132 - val_accuracy: 0.7183 - val_loss: 0.9344
# Epoch 31/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 173ms/step - accuracy: 0.7363 - loss: 0.8102 - val_accuracy: 0.7186 - val_loss: 0.9106
# Epoch 32/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - accuracy: 0.7345 - loss: 0.7821 - val_accuracy: 0.7034 - val_loss: 1.0300
# Epoch 33/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - accuracy: 0.7661 - loss: 0.7214 - val_accuracy: 0.7379 - val_loss: 0.8781
# Epoch 34/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 22s 179ms/step - accuracy: 0.7698 - loss: 0.7082 - val_accuracy: 0.6968 - val_loss: 0.9988
# Epoch 35/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 21s 173ms/step - accuracy: 0.7809 - loss: 0.6808 - val_accuracy: 0.7523 - val_loss: 0.8334
# Epoch 36/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.7715 - loss: 0.6652 - val_accuracy: 0.7565 - val_loss: 0.9013
# Epoch 37/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.7939 - loss: 0.6405 - val_accuracy: 0.7663 - val_loss: 0.8025
# Epoch 38/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.8013 - loss: 0.5966 - val_accuracy: 0.7279 - val_loss: 0.9926
# Epoch 39/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 163ms/step - accuracy: 0.7917 - loss: 0.6125 - val_accuracy: 0.7493 - val_loss: 0.8550
# Epoch 40/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.8105 - loss: 0.5957 - val_accuracy: 0.7711 - val_loss: 0.7635
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 15s 123ms/step - accuracy: 0.8416 - loss: 0.4478
# Training accuracy: 0.8524246215820312
# Training Loss: 0.43127280473709106
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.7764 - loss: 0.7755
# Validation accuracy: 0.7710875272750854
# Validation Loss: 0.7634828090667725
# Found 3770 files belonging to 37 classes.
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']
# 3770/3770 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step

# %%
cnn.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_40 (Conv2D)              │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 126, 126, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 63, 63, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 61, 61, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_44 (Conv2D)              │ (None, 30, 30, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_45 (Conv2D)              │ (None, 28, 28, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_46 (Conv2D)              │ (None, 14, 14, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_47 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_48 (Conv2D)              │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_49 (Conv2D)              │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1020)           │     2,089,980 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 1020)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 37)             │        37,777 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,519,945 (78.28 MB)
#  Trainable params: 6,839,981 (26.09 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 13,679,964 (52.18 MB)

# %% [markdown]
# # **VGG16 MODEL**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report

#  Load Training Dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/train",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(224, 224),  # VGG16 requires 224x224 input
    shuffle=True
)

#  Load Validation Dataset
valid_dataset = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/val",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(224, 224),
    shuffle=False
)

#  Get Class Names
class_names = train_dataset.class_names
num_classes = len(class_names)

#  Data Augmentation & Normalization
data_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.2),
    RandomZoom(0.2),
])
normalization_layer = Rescaling(1.0 / 255)

#  Apply Augmentation & Normalization
train_dataset = train_dataset.map(lambda x, y: (data_augmentation(normalization_layer(x)), y))
valid_dataset = valid_dataset.map(lambda x, y: (normalization_layer(x), y))

#  VGG16 Model
def build_vgg16_model(num_classes, input_shape=(224, 224, 3)):  #  Fixed input shape
    base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False  # Freeze base model initially

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dense(512, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    return model

#  Compile Model
vgg16_model = build_vgg16_model(num_classes)
vgg16_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

#  Define Callbacks
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

#  Train Model
vgg16_history = vgg16_model.fit(train_dataset, validation_data=valid_dataset, epochs=40, callbacks=[lr_scheduler, early_stopping])

#  Evaluate Model on Validation Set
val_loss, val_acc = vgg16_model.evaluate(valid_dataset)
print(f'VGG16 - Validation Accuracy: {val_acc:.4f}')
# print(f'VGG16 - Validation Loss: {val_loss:.4f}')

#  Evaluate Model on Training Set
train_loss, train_acc = vgg16_model.evaluate(train_dataset)
print(f'VGG16 - Training Accuracy: {train_acc:.4f}')
# print(f'VGG16 - Training Loss: {train_loss:.4f}')

# Save the trained model
vgg16_model.save('trained_plant_disease_VGG16_model.keras')

# #  Confusion Matrix
# y_pred = vgg16_model.predict(valid_dataset)
# predicted_categories = tf.argmax(y_pred, axis=1)
# true_categories = tf.concat([y for x, y in valid_dataset], axis=0)
# Y_true = tf.argmax(true_categories, axis=1)

# cm_vgg16 = confusion_matrix(Y_true, predicted_categories)

# #  Plot Confusion Matrix
# plt.figure(figsize=(10, 8))
# sns.heatmap(cm_vgg16, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
# plt.xlabel('Predicted Class')
# plt.ylabel('Actual Class')
# plt.title('VGG16 Confusion Matrix')
# plt.show()

#  Plot Accuracy & Loss Graphs
epochs = range(1, len(vgg16_history.history['accuracy']) + 1)

plt.figure(figsize=(12, 5))

#  Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, vgg16_history.history['accuracy'], color='red', label='Training Accuracy')
plt.plot(epochs, vgg16_history.history['val_accuracy'], color='blue', label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()

#  Plot Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, vgg16_history.history['loss'], color='red', label='Training Loss')
plt.plot(epochs, vgg16_history.history['val_loss'], color='blue', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()

plt.show()


#  Healthy vs Unhealthy Confusion Matrix for VGG16
healthy_classes = [cls for cls in class_names if 'healthy' in cls.lower()]
healthy_class_indices = [class_names.index(cls) for cls in healthy_classes]

# Predict with VGG16 Model (on the validation dataset)
y_pred_probs = vgg16_model.predict(valid_dataset)
y_pred = tf.argmax(y_pred_probs, axis=1)

# Convert true labels to indices
true_categories = tf.concat([y for x, y in valid_dataset], axis=0)
true_categories = tf.argmax(true_categories, axis=1)

# Convert to binary classification (healthy=1, unhealthy=0)
y_true_binary = [1 if label in healthy_class_indices else 0 for label in true_categories.numpy()]
y_pred_binary = [1 if label in healthy_class_indices else 0 for label in y_pred.numpy()]

# Classification report and confusion matrix for healthy vs unhealthy
print("\nHealthy vs Unhealthy Classification Report:")
print(classification_report(y_true_binary, y_pred_binary, target_names=["Unhealthy", "Healthy"]))

# Compute confusion matrix for healthy vs unhealthy
cm = confusion_matrix(y_true_binary, y_pred_binary)

# Plot healthy/unhealthy confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=["Unhealthy", "Healthy"], yticklabels=["Unhealthy", "Healthy"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Healthy vs Unhealthy Confusion Matrix")
plt.tight_layout()
plt.show()

# Count predictions
import numpy as np

labels = ["Unhealthy", "Healthy"]
counts = np.bincount(y_pred_binary)  # [count_unhealthy, count_healthy]

# Pie chart
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140, colors=['#FF9999', '#99FF99'])
plt.title("Predicted Distribution: Healthy vs Unhealthy")
plt.axis('equal')  # Equal aspect ratio ensures pie is a circle.
plt.show()
# Out:
# Found 3815 files belonging to 37 classes.
# Found 3770 files belonging to 37 classes.
# Epoch 1/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 67s 541ms/step - accuracy: 0.0604 - loss: 3.5687 - val_accuracy: 0.2501 - val_loss: 3.2915 - learning_rate: 1.0000e-04
# Epoch 2/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 523ms/step - accuracy: 0.2566 - loss: 3.1589 - val_accuracy: 0.3573 - val_loss: 2.7878 - learning_rate: 1.0000e-04
# Epoch 3/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 67s 556ms/step - accuracy: 0.3823 - loss: 2.6270 - val_accuracy: 0.4721 - val_loss: 2.3011 - learning_rate: 1.0000e-04
# Epoch 4/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 65s 542ms/step - accuracy: 0.5145 - loss: 2.1644 - val_accuracy: 0.5050 - val_loss: 1.9729 - learning_rate: 1.0000e-04
# Epoch 5/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 522ms/step - accuracy: 0.5559 - loss: 1.8513 - val_accuracy: 0.5406 - val_loss: 1.7498 - learning_rate: 1.0000e-04
# Epoch 6/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 62s 517ms/step - accuracy: 0.6065 - loss: 1.6020 - val_accuracy: 0.5849 - val_loss: 1.5722 - learning_rate: 1.0000e-04
# Epoch 7/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 524ms/step - accuracy: 0.6288 - loss: 1.4519 - val_accuracy: 0.5905 - val_loss: 1.4663 - learning_rate: 1.0000e-04
# Epoch 8/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 529ms/step - accuracy: 0.6618 - loss: 1.2986 - val_accuracy: 0.6244 - val_loss: 1.3599 - learning_rate: 1.0000e-04
# Epoch 9/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 65s 541ms/step - accuracy: 0.6618 - loss: 1.2208 - val_accuracy: 0.6504 - val_loss: 1.2665 - learning_rate: 1.0000e-04
# Epoch 10/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 528ms/step - accuracy: 0.7006 - loss: 1.1514 - val_accuracy: 0.6477 - val_loss: 1.2428 - learning_rate: 1.0000e-04
# Epoch 11/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 521ms/step - accuracy: 0.6975 - loss: 1.0865 - val_accuracy: 0.6700 - val_loss: 1.1698 - learning_rate: 1.0000e-04
# Epoch 12/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 528ms/step - accuracy: 0.7365 - loss: 1.0036 - val_accuracy: 0.6562 - val_loss: 1.1823 - learning_rate: 1.0000e-04
# Epoch 13/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 529ms/step - accuracy: 0.7333 - loss: 0.9657 - val_accuracy: 0.6761 - val_loss: 1.1109 - learning_rate: 1.0000e-04
# Epoch 14/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 62s 513ms/step - accuracy: 0.7408 - loss: 0.9206 - val_accuracy: 0.6859 - val_loss: 1.0917 - learning_rate: 1.0000e-04
# Epoch 15/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 526ms/step - accuracy: 0.7552 - loss: 0.8775 - val_accuracy: 0.6971 - val_loss: 1.0545 - learning_rate: 1.0000e-04
# Epoch 16/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 535ms/step - accuracy: 0.7464 - loss: 0.8738 - val_accuracy: 0.6854 - val_loss: 1.0702 - learning_rate: 1.0000e-04
# Epoch 17/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 527ms/step - accuracy: 0.7456 - loss: 0.8493 - val_accuracy: 0.7013 - val_loss: 1.0106 - learning_rate: 1.0000e-04
# Epoch 18/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 61s 511ms/step - accuracy: 0.7624 - loss: 0.7985 - val_accuracy: 0.6798 - val_loss: 1.0839 - learning_rate: 1.0000e-04
# Epoch 19/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 62s 513ms/step - accuracy: 0.7699 - loss: 0.7894 - val_accuracy: 0.6928 - val_loss: 1.0490 - learning_rate: 1.0000e-04
# Epoch 20/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 534ms/step - accuracy: 0.7875 - loss: 0.7467 - val_accuracy: 0.7263 - val_loss: 0.9412 - learning_rate: 1.0000e-04
# Epoch 21/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 61s 508ms/step - accuracy: 0.8033 - loss: 0.7119 - val_accuracy: 0.7210 - val_loss: 0.9656 - learning_rate: 1.0000e-04
# Epoch 22/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 62s 518ms/step - accuracy: 0.7873 - loss: 0.7383 - val_accuracy: 0.7180 - val_loss: 0.9871 - learning_rate: 1.0000e-04
# Epoch 23/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 66s 549ms/step - accuracy: 0.7813 - loss: 0.7221 - val_accuracy: 0.7191 - val_loss: 0.9655 - learning_rate: 1.0000e-04
# Epoch 24/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 526ms/step - accuracy: 0.7921 - loss: 0.6836 - val_accuracy: 0.7228 - val_loss: 0.9522 - learning_rate: 1.0000e-04
# Epoch 25/40
# 119/120 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.7938 - loss: 0.6687
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 61s 506ms/step - accuracy: 0.7938 - loss: 0.6689 - val_accuracy: 0.7225 - val_loss: 0.9462 - learning_rate: 1.0000e-04
# Epoch 26/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 521ms/step - accuracy: 0.8094 - loss: 0.6447 - val_accuracy: 0.7326 - val_loss: 0.9057 - learning_rate: 5.0000e-05
# Epoch 27/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 521ms/step - accuracy: 0.8325 - loss: 0.6004 - val_accuracy: 0.7300 - val_loss: 0.9178 - learning_rate: 5.0000e-05
# Epoch 28/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 530ms/step - accuracy: 0.8284 - loss: 0.6043 - val_accuracy: 0.7363 - val_loss: 0.9054 - learning_rate: 5.0000e-05
# Epoch 29/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 527ms/step - accuracy: 0.8218 - loss: 0.6235 - val_accuracy: 0.7427 - val_loss: 0.8846 - learning_rate: 5.0000e-05
# Epoch 30/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 62s 517ms/step - accuracy: 0.8214 - loss: 0.6105 - val_accuracy: 0.7408 - val_loss: 0.8922 - learning_rate: 5.0000e-05
# Epoch 31/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 536ms/step - accuracy: 0.8277 - loss: 0.5963 - val_accuracy: 0.7231 - val_loss: 0.9360 - learning_rate: 5.0000e-05
# Epoch 32/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 66s 550ms/step - accuracy: 0.8210 - loss: 0.5794 - val_accuracy: 0.7292 - val_loss: 0.9282 - learning_rate: 5.0000e-05
# Epoch 33/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 536ms/step - accuracy: 0.8242 - loss: 0.5893 - val_accuracy: 0.7371 - val_loss: 0.8977 - learning_rate: 5.0000e-05
# Epoch 34/40
# 119/120 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8298 - loss: 0.5800
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 527ms/step - accuracy: 0.8298 - loss: 0.5800 - val_accuracy: 0.7371 - val_loss: 0.8868 - learning_rate: 5.0000e-05
# Epoch 35/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 531ms/step - accuracy: 0.8295 - loss: 0.5653 - val_accuracy: 0.7493 - val_loss: 0.8576 - learning_rate: 2.5000e-05
# Epoch 36/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 529ms/step - accuracy: 0.8302 - loss: 0.5639 - val_accuracy: 0.7480 - val_loss: 0.8599 - learning_rate: 2.5000e-05
# Epoch 37/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 65s 539ms/step - accuracy: 0.8424 - loss: 0.5474 - val_accuracy: 0.7456 - val_loss: 0.8639 - learning_rate: 2.5000e-05
# Epoch 38/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 62s 519ms/step - accuracy: 0.8303 - loss: 0.5554 - val_accuracy: 0.7483 - val_loss: 0.8680 - learning_rate: 2.5000e-05
# Epoch 39/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 528ms/step - accuracy: 0.8322 - loss: 0.5574 - val_accuracy: 0.7430 - val_loss: 0.8759 - learning_rate: 2.5000e-05
# Epoch 40/40
# 119/120 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8302 - loss: 0.5741
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 64s 530ms/step - accuracy: 0.8302 - loss: 0.5740 - val_accuracy: 0.7493 - val_loss: 0.8586 - learning_rate: 2.5000e-05
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 163ms/step - accuracy: 0.7971 - loss: 0.7119
# VGG16 - Validation Accuracy: 0.7493
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 368ms/step - accuracy: 0.8387 - loss: 0.5616
# VGG16 - Training Accuracy: 0.8341
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 21s 173ms/step
#
# Healthy vs Unhealthy Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       0.99      0.87      0.93      2800
#      Healthy       0.72      0.97      0.83       970
#
#     accuracy                           0.90      3770
#    macro avg       0.86      0.92      0.88      3770
# weighted avg       0.92      0.90      0.90      3770

# %% [markdown]
# ## **MOBILENET**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Load Training Dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/train",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(224, 224),
    shuffle=True
)

# Load Validation Dataset
valid_dataset = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/val",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(224, 224),
    shuffle=False
)

# Get Class Names
class_names = train_dataset.class_names
num_classes = len(class_names)

# Data Augmentation & Normalization
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
])
normalization_layer = tf.keras.layers.Rescaling(1.0 / 255)

# Apply Augmentation & Normalization
train_dataset = train_dataset.map(lambda x, y: (data_augmentation(normalization_layer(x)), y))
valid_dataset = valid_dataset.map(lambda x, y: (normalization_layer(x), y))

#  Define MobileNet Model
def build_mobilenet_model(num_classes):
    base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False  # Freeze base model initially

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    return model

# Build & Compile MobileNet Model
mobilenet_model = build_mobilenet_model(num_classes)
mobilenet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

# Define Callbacks
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

# Train the MobileNet Model
mobilenet_history = mobilenet_model.fit(train_dataset, validation_data=valid_dataset, epochs=40, callbacks=[lr_scheduler, early_stopping])

# Evaluate the Model on Validation Set
val_loss, val_acc = mobilenet_model.evaluate(valid_dataset)
print(f'\n MobileNet - Validation Accuracy: {val_acc:.4f}')
# print(f' MobileNet - Validation Loss: {val_loss:.4f}')

# Evaluate the Model on Training Set
train_loss, train_acc = mobilenet_model.evaluate(train_dataset)
print(f'\n MobileNet - Training Accuracy: {train_acc:.4f}')  # Fixed label
# print(f' MobileNet - Training Loss: {train_loss:.4f}')  # Fixed label

# Save the Model
mobilenet_model.save('mobilenet_plant_disease_model.keras')

#  Plot Accuracy & Loss Graphs
epochs = range(1, len(mobilenet_history.history['accuracy']) + 1)

plt.figure(figsize=(12, 5))

#  Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, mobilenet_history.history['accuracy'], color='red', label='Training Accuracy')
plt.plot(epochs, mobilenet_history.history['val_accuracy'], color='blue', label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()

#  Plot Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, mobilenet_history.history['loss'], color='red', label='Training Loss')
plt.plot(epochs, mobilenet_history.history['val_loss'], color='blue', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()

plt.show()

#  Evaluate with Confusion Matrix for Healthy vs Unhealthy

# Identify healthy and unhealthy classes
healthy_classes = [cls for cls in class_names if 'healthy' in cls.lower()]
healthy_class_indices = [class_names.index(cls) for cls in healthy_classes]

# Print all class names with index and label (Healthy / Unhealthy)
print("\n=== Full Class List ===")
for idx, cls in enumerate(class_names):
    label = "Healthy" if idx in healthy_class_indices else "Unhealthy"
    print(f"{idx:>2}: {cls:<30} → {label}")

# Predict with MobileNet Model (on the validation dataset)
y_pred_probs = mobilenet_model.predict(valid_dataset)
y_pred = tf.argmax(y_pred_probs, axis=1)

# Convert true labels to indices
true_categories = tf.concat([y for x, y in valid_dataset], axis=0)
true_categories = tf.argmax(true_categories, axis=1)

# Convert to binary classification (healthy=1, unhealthy=0)
y_true_binary = [1 if label in healthy_class_indices else 0 for label in true_categories.numpy()]
y_pred_binary = [1 if label in healthy_class_indices else 0 for label in y_pred.numpy()]

# Classification report and confusion matrix
print("\nHealthy vs Unhealthy Classification Report:")
print(classification_report(y_true_binary, y_pred_binary, target_names=["Unhealthy", "Healthy"]))

# Compute confusion matrix
cm = confusion_matrix(y_true_binary, y_pred_binary)

# Plot healthy/unhealthy confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Unhealthy", "Healthy"], yticklabels=["Unhealthy", "Healthy"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Healthy vs Unhealthy Confusion Matrix")
plt.tight_layout()
plt.show()
# Save the Model
mobilenet_model.save('mobilenet_plant_disease_model.keras')

# report = classification_report(y_true_binary, y_pred_binary, target_names=["Unhealthy", "Healthy"], output_dict=True)
# metrics = {
#     'Precision': [report['Unhealthy']['precision'], report['Healthy']['precision']],
#     'Recall': [report['Unhealthy']['recall'], report['Healthy']['recall']],
#     'F1-Score': [report['Unhealthy']['f1-score'], report['Healthy']['f1-score']]
# }

# # Create an array for the x-axis positions of each group (Healthy, Unhealthy)
# x = np.arange(2)  # Two classes: Unhealthy and Healthy
# width = 0.2  # The width of the bars

# # Create a single figure
# fig, ax = plt.subplots(figsize=(10, 6))


# # Add labels and title
# ax.set_xlabel('Classes')
# ax.set_ylabel('Scores')
# ax.set_title('Comparison of Precision, Recall, and F1-Score for Healthy vs Unhealthy')
# ax.set_xticks(x)
# ax.set_xticklabels(['Unhealthy', 'Healthy'])
# ax.set_ylim(0, 1)  # Set the y-axis to go from 0 to 1 (since metrics are between 0 and 1)
# ax.legend()

# # Show the plot
# plt.tight_layout()
# plt.show()

# Assuming you have predictions in y_pred_binary
labels = ['Unhealthy', 'Healthy']
sizes = [sum([1 for x in y_pred_binary if x == 0]), sum([1 for x in y_pred_binary if x == 1])]

# Plot Pie Chart
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'])
plt.title("Healthy vs Unhealthy Predictions (Pie Chart)")
plt.show()
# Out:
# Found 3815 files belonging to 37 classes.
# Found 3770 files belonging to 37 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 63s 450ms/step - accuracy: 0.1286 - loss: 3.4104 - val_accuracy: 0.5408 - val_loss: 2.1527 - learning_rate: 1.0000e-04
# Epoch 2/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 376ms/step - accuracy: 0.5300 - loss: 1.9154 - val_accuracy: 0.6987 - val_loss: 1.3696 - learning_rate: 1.0000e-04
# Epoch 3/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 375ms/step - accuracy: 0.6726 - loss: 1.2910 - val_accuracy: 0.7512 - val_loss: 1.0562 - learning_rate: 1.0000e-04
# Epoch 4/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 370ms/step - accuracy: 0.7376 - loss: 1.0043 - val_accuracy: 0.7828 - val_loss: 0.8892 - learning_rate: 1.0000e-04
# Epoch 5/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 372ms/step - accuracy: 0.7791 - loss: 0.8437 - val_accuracy: 0.8027 - val_loss: 0.7982 - learning_rate: 1.0000e-04
# Epoch 6/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 375ms/step - accuracy: 0.7983 - loss: 0.7227 - val_accuracy: 0.8090 - val_loss: 0.7403 - learning_rate: 1.0000e-04
# Epoch 7/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 372ms/step - accuracy: 0.8064 - loss: 0.6732 - val_accuracy: 0.8159 - val_loss: 0.7080 - learning_rate: 1.0000e-04
# Epoch 8/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 375ms/step - accuracy: 0.8409 - loss: 0.5847 - val_accuracy: 0.8231 - val_loss: 0.6560 - learning_rate: 1.0000e-04
# Epoch 9/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 373ms/step - accuracy: 0.8476 - loss: 0.5242 - val_accuracy: 0.8255 - val_loss: 0.6279 - learning_rate: 1.0000e-04
# Epoch 10/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 376ms/step - accuracy: 0.8692 - loss: 0.4922 - val_accuracy: 0.8347 - val_loss: 0.6058 - learning_rate: 1.0000e-04
# Epoch 11/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 373ms/step - accuracy: 0.8635 - loss: 0.4652 - val_accuracy: 0.8329 - val_loss: 0.6027 - learning_rate: 1.0000e-04
# Epoch 12/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 375ms/step - accuracy: 0.8748 - loss: 0.4297 - val_accuracy: 0.8395 - val_loss: 0.5852 - learning_rate: 1.0000e-04
# Epoch 13/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 373ms/step - accuracy: 0.8839 - loss: 0.4084 - val_accuracy: 0.8353 - val_loss: 0.5894 - learning_rate: 1.0000e-04
# Epoch 14/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 375ms/step - accuracy: 0.8871 - loss: 0.4007 - val_accuracy: 0.8438 - val_loss: 0.5558 - learning_rate: 1.0000e-04
# Epoch 15/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 373ms/step - accuracy: 0.8896 - loss: 0.3936 - val_accuracy: 0.8403 - val_loss: 0.5566 - learning_rate: 1.0000e-04
# Epoch 16/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.8877 - loss: 0.3733 - val_accuracy: 0.8408 - val_loss: 0.5560 - learning_rate: 1.0000e-04
# Epoch 17/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 373ms/step - accuracy: 0.8938 - loss: 0.3474 - val_accuracy: 0.8472 - val_loss: 0.5315 - learning_rate: 1.0000e-04
# Epoch 18/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.8987 - loss: 0.3416 - val_accuracy: 0.8483 - val_loss: 0.5258 - learning_rate: 1.0000e-04
# Epoch 19/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 372ms/step - accuracy: 0.8992 - loss: 0.3408 - val_accuracy: 0.8469 - val_loss: 0.5479 - learning_rate: 1.0000e-04
# Epoch 20/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.9083 - loss: 0.3035 - val_accuracy: 0.8499 - val_loss: 0.5409 - learning_rate: 1.0000e-04
# Epoch 21/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 373ms/step - accuracy: 0.9046 - loss: 0.3220 - val_accuracy: 0.8533 - val_loss: 0.5368 - learning_rate: 1.0000e-04
# Epoch 22/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 375ms/step - accuracy: 0.9075 - loss: 0.3025 - val_accuracy: 0.8538 - val_loss: 0.5162 - learning_rate: 1.0000e-04
# Epoch 23/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 370ms/step - accuracy: 0.9247 - loss: 0.2670 - val_accuracy: 0.8544 - val_loss: 0.5052 - learning_rate: 1.0000e-04
# Epoch 24/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.9252 - loss: 0.2692 - val_accuracy: 0.8584 - val_loss: 0.5109 - learning_rate: 1.0000e-04
# Epoch 25/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 370ms/step - accuracy: 0.9283 - loss: 0.2502 - val_accuracy: 0.8549 - val_loss: 0.5102 - learning_rate: 1.0000e-04
# Epoch 26/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 373ms/step - accuracy: 0.9233 - loss: 0.2558 - val_accuracy: 0.8560 - val_loss: 0.5065 - learning_rate: 1.0000e-04
# Epoch 27/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 372ms/step - accuracy: 0.9164 - loss: 0.2636 - val_accuracy: 0.8599 - val_loss: 0.4938 - learning_rate: 1.0000e-04
# Epoch 28/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.9307 - loss: 0.2348 - val_accuracy: 0.8615 - val_loss: 0.5055 - learning_rate: 1.0000e-04
# Epoch 29/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 368ms/step - accuracy: 0.9291 - loss: 0.2412 - val_accuracy: 0.8584 - val_loss: 0.4911 - learning_rate: 1.0000e-04
# Epoch 30/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 373ms/step - accuracy: 0.9344 - loss: 0.2287 - val_accuracy: 0.8573 - val_loss: 0.5094 - learning_rate: 1.0000e-04
# Epoch 31/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 371ms/step - accuracy: 0.9267 - loss: 0.2301 - val_accuracy: 0.8634 - val_loss: 0.5053 - learning_rate: 1.0000e-04
# Epoch 32/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.9335 - loss: 0.2237 - val_accuracy: 0.8642 - val_loss: 0.4872 - learning_rate: 1.0000e-04
# Epoch 33/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 368ms/step - accuracy: 0.9432 - loss: 0.2031 - val_accuracy: 0.8602 - val_loss: 0.5073 - learning_rate: 1.0000e-04
# Epoch 34/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 375ms/step - accuracy: 0.9355 - loss: 0.2121 - val_accuracy: 0.8610 - val_loss: 0.4815 - learning_rate: 1.0000e-04
# Epoch 35/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 369ms/step - accuracy: 0.9345 - loss: 0.2099 - val_accuracy: 0.8660 - val_loss: 0.4758 - learning_rate: 1.0000e-04
# Epoch 36/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.9373 - loss: 0.2068 - val_accuracy: 0.8629 - val_loss: 0.5103 - learning_rate: 1.0000e-04
# Epoch 37/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 372ms/step - accuracy: 0.9381 - loss: 0.2212 - val_accuracy: 0.8721 - val_loss: 0.4557 - learning_rate: 1.0000e-04
# Epoch 38/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 375ms/step - accuracy: 0.9446 - loss: 0.1928 - val_accuracy: 0.8690 - val_loss: 0.4816 - learning_rate: 1.0000e-04
# Epoch 39/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 372ms/step - accuracy: 0.9439 - loss: 0.1870 - val_accuracy: 0.8708 - val_loss: 0.4811 - learning_rate: 1.0000e-04
# Epoch 40/40
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 376ms/step - accuracy: 0.9390 - loss: 0.1804 - val_accuracy: 0.8645 - val_loss: 0.4879 - learning_rate: 1.0000e-04
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9062 - loss: 0.3466
#
#  MobileNet - Validation Accuracy: 0.8721
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 41s 344ms/step - accuracy: 0.9690 - loss: 0.1363
#
#  MobileNet - Training Accuracy: 0.9630
# === Full Class List ===
#  0: Apple___Apple_scab             → Unhealthy
#  1: Apple___Black_rot              → Unhealthy
#  2: Apple___Cedar_apple_rust       → Unhealthy
#  3: Apple___healthy                → Healthy
#  4: Blueberry___healthy            → Healthy
#  5: Cherry_(including_sour)___Powdery_mildew → Unhealthy
#  6: Cherry_(including_sour)___healthy → Healthy
#  7: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot → Unhealthy
#  8: Corn_(maize)___Common_rust_    → Unhealthy
#  9: Corn_(maize)___Northern_Leaf_Blight → Unhealthy
# 10: Corn_(maize)___healthy         → Healthy
# 11: Grape___Black_rot              → Unhealthy
# 12: Grape___Esca_(Black_Measles)   → Unhealthy
# 13: Grape___Leaf_blight_(Isariopsis_Leaf_Spot) → Unhealthy
# 14: Grape___healthy                → Healthy
# 15: Orange___Haunglongbing_(Citrus_greening) → Unhealthy
# 16: Peach___Bacterial_spot         → Unhealthy
# 17: Peach___healthy                → Healthy
# 18: Pepper,_bell___Bacterial_spot  → Unhealthy
# 19: Pepper,_bell___healthy         → Healthy
# 20: Potato___Early_blight          → Unhealthy
# 21: Potato___Late_blight           → Unhealthy
# 22: Potato___healthy               → Healthy
# 23: Raspberry___healthy            → Healthy
# 24: Squash___Powdery_mildew        → Unhealthy
# 25: Strawberry___Leaf_scorch       → Unhealthy
# 26: Strawberry___healthy           → Healthy
# 27: Tomato___Bacterial_spot        → Unhealthy
# 28: Tomato___Early_blight          → Unhealthy
# 29: Tomato___Late_blight           → Unhealthy
# 30: Tomato___Leaf_Mold             → Unhealthy
# 31: Tomato___Septoria_leaf_spot    → Unhealthy
# 32: Tomato___Spider_mites Two-spotted_spider_mite → Unhealthy
# 33: Tomato___Target_Spot           → Unhealthy
# 34: Tomato___Tomato_Yellow_Leaf_Curl_Virus → Unhealthy
# 35: Tomato___Tomato_mosaic_virus   → Unhealthy
# 36: Tomato___healthy               → Healthy
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step
#
# Healthy vs Unhealthy Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       1.00      0.94      0.97      2800
#      Healthy       0.86      0.99      0.92       970
#
#     accuracy                           0.95      3770
#    macro avg       0.93      0.96      0.94      3770
# weighted avg       0.96      0.95      0.95      3770

# %% [markdown]
# # **MODEL COMPARISIONS**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, accuracy_score, f1_score, precision_recall_fscore_support

# --- Load validation datasets ---
valid_dataset_cnn_raw = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/val",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(128, 128),
    shuffle=False
)

valid_dataset_large_raw = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/val",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(224, 224),
    shuffle=False
)

class_names_cnn = valid_dataset_cnn_raw.class_names
class_names_large = valid_dataset_large_raw.class_names

print("CNN Class Names:", class_names_cnn)
print("VGG16/MobileNet Class Names:", class_names_large)

# --- Apply Rescaling ---
valid_dataset_cnn = valid_dataset_cnn_raw.map(lambda x, y: (tf.keras.layers.Rescaling(1./255)(x), y))
valid_dataset_large = valid_dataset_large_raw.map(lambda x, y: (tf.keras.layers.Rescaling(1./255)(x), y))

# --- Load models ---
cnn_model = tf.keras.models.load_model('/content/drive/MyDrive/PLANT MODELS COMPARISION/trained_plant_disease_model (3).keras')
vgg16_model = tf.keras.models.load_model('/content/drive/MyDrive/PLANT MODELS COMPARISION/trained_plant_disease_VGG16_model (1).keras')
mobilenet_model = tf.keras.models.load_model('/content/drive/MyDrive/PLANT MODELS COMPARISION/mobilenet_plant_disease_model.keras')

# --- Helper: Binary Healthy/Unhealthy ---
def to_binary_labels(class_names, labels):
    healthy_class_indices = [i for i, cls in enumerate(class_names) if 'healthy' in cls.lower()]
    return [1 if label in healthy_class_indices else 0 for label in labels]

# --- Evaluate model ---
def evaluate_model(model, dataset, name, class_names):
    y_true = []
    y_pred = []

    for images, labels in dataset:
        preds = model.predict(images)
        y_true.extend(to_binary_labels(class_names, np.argmax(labels.numpy(), axis=1)))
        y_pred.extend(to_binary_labels(class_names, np.argmax(preds, axis=1)))

    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    print(f"\n Evaluation for {name}:")
    print(classification_report(y_true, y_pred, target_names=["Unhealthy", "Healthy"]))

    cm = confusion_matrix(y_true, y_pred)

    # Plot Confusion Matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Unhealthy", "Healthy"], yticklabels=["Unhealthy", "Healthy"])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"{name} - Confusion Matrix")
    plt.tight_layout()
    plt.show()

    # --- Per-class precision, recall, f1 for binary (0: Unhealthy, 1: Healthy) ---
    per_class_precision, per_class_recall, per_class_f1, _ = precision_recall_fscore_support(y_true, y_pred, labels=[0, 1], zero_division=0)

    # --- Per-class Bar Chart ---
    x = np.arange(len(per_class_precision))  # [0, 1]
    width = 0.25
    fig, ax = plt.subplots(figsize=(10, 6))

    ax.bar(x - width, per_class_precision, width, label='Precision', color='#ff9999')
    ax.bar(x, per_class_recall, width, label='Recall', color='#66b3ff')
    ax.bar(x + width, per_class_f1, width, label='F1-Score', color='#99ff99')

    ax.set_xlabel('Classes')
    ax.set_ylabel('Scores')
    ax.set_title(f'{name} - Precision, Recall, F1-Score per Class')
    ax.set_xticks(x)
    ax.set_xticklabels(['Unhealthy', 'Healthy'])
    ax.set_ylim(0, 1.05)
    ax.legend()
    plt.tight_layout()
    plt.show()

    return precision, recall, accuracy, f1, cm

# --- Evaluate all models ---
precision_cnn, recall_cnn, acc_cnn, f1_cnn, cm_cnn = evaluate_model(cnn_model, valid_dataset_cnn, "CNN (128x128)", class_names_cnn)
precision_vgg, recall_vgg, acc_vgg, f1_vgg, cm_vgg = evaluate_model(vgg16_model, valid_dataset_large, "VGG16 (224x224)", class_names_large)
precision_mob, recall_mob, acc_mob, f1_mob, cm_mob = evaluate_model(mobilenet_model, valid_dataset_large, "MobileNet (224x224)", class_names_large)

# # --- Model Comparison Summary Plot ---
# models = ['CNN', 'VGG16', 'MobileNet']
# accuracies = [acc_cnn, acc_vgg, acc_mob]
# precisions = [precision_cnn, precision_vgg, precision_mob]
# recalls = [recall_cnn, recall_vgg, recall_mob]
# f1_scores = [f1_cnn, f1_vgg, f1_mob]

# x = np.arange(len(models))
# width = 0.2

# plt.figure(figsize=(12, 6))
# plt.bar(x - width, accuracies, width, label='Accuracy', color='skyblue')
# plt.bar(x, precisions, width, label='Precision', color='lightgreen')
# plt.bar(x + width, recalls, width, label='Recall', color='salmon')
# plt.bar(x + 2*width, f1_scores, width, label='F1-Score', color='orange')

# for i in range(len(models)):
#     plt.text(x[i] - width, accuracies[i] + 0.01, f'{accuracies[i]:.2f}', ha='center')
#     plt.text(x[i], precisions[i] + 0.01, f'{precisions[i]:.2f}', ha='center')
#     plt.text(x[i] + width, recalls[i] + 0.01, f'{recalls[i]:.2f}', ha='center')
#     plt.text(x[i] + 2*width, f1_scores[i] + 0.01, f'{f1_scores[i]:.2f}', ha='center')

# plt.ylabel('Score')
# plt.title('Model Comparison: Accuracy, Precision, Recall, F1-Score')
# plt.xticks(x, models)
# plt.ylim(0, 1.2)
# plt.legend()
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()


#  Function to generate pie chart for predicted distributions
def plot_prediction_distribution(model, dataset, class_names, model_name):
    y_pred_binary = []
    for images, _ in dataset:
        preds = model.predict(images)
        y_pred_binary.extend(to_binary_labels(class_names, np.argmax(preds, axis=1)))

    # Count predictions for each class
    labels_pie = ["Unhealthy", "Healthy"]
    counts = np.bincount(y_pred_binary)

    # Plot pie chart
    plt.figure(figsize=(6, 6))
    plt.pie(counts, labels=labels_pie, autopct='%1.1f%%', startangle=140, colors=['#FF9999', '#99FF99'])
    plt.title(f"{model_name} Prediction Distribution: Healthy vs Unhealthy")
    plt.axis('equal')  # Circle shape
    plt.tight_layout()
    plt.show()

# --- Generate pie charts for all models ---
plot_prediction_distribution(cnn_model, valid_dataset_cnn, class_names_cnn, "CNN")
plot_prediction_distribution(vgg16_model, valid_dataset_large, class_names_large, "VGG16")
plot_prediction_distribution(mobilenet_model, valid_dataset_large, class_names_large, "MobileNet")
# Out:
# Found 3770 files belonging to 37 classes.
# Found 3770 files belonging to 37 classes.
# CNN Class Names: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']
# VGG16/MobileNet Class Names: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
#
#  Evaluation for CNN (128x128):
#               precision    recall  f1-score   support
#
#    Unhealthy       0.97      0.93      0.95      2800
#      Healthy       0.81      0.92      0.86       970
#
#     accuracy                           0.92      3770
#    macro avg       0.89      0.92      0.90      3770
# weighted avg       0.93      0.92      0.92      3770
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 863ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
#
#  Evaluation for VGG16 (224x224):
#               precision    recall  f1-score   support
#
#    Unhealthy       0.99      0.89      0.94      2800
#      Healthy       0.75      0.97      0.85       970
#
#     accuracy                           0.91      3770
#    macro avg       0.87      0.93      0.89      3770
# weighted avg       0.93      0.91      0.91      3770
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#
#  Evaluation for MobileNet (224x224):
#               precision    recall  f1-score   support
#
#    Unhealthy       1.00      0.94      0.97      2800
#      Healthy       0.84      0.99      0.91       970
#
#     accuracy                           0.95      3770
#    macro avg       0.92      0.96      0.94      3770
# weighted avg       0.96      0.95      0.95      3770
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# --- Load datasets ---
valid_dataset_cnn_raw = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/val",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(128, 128),
    shuffle=False
)

valid_dataset_large_raw = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/val",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    image_size=(224, 224),
    shuffle=False
)

class_names_cnn = valid_dataset_cnn_raw.class_names
class_names_large = valid_dataset_large_raw.class_names

valid_dataset_cnn = valid_dataset_cnn_raw.map(lambda x, y: (tf.keras.layers.Rescaling(1./255)(x), y))
valid_dataset_large = valid_dataset_large_raw.map(lambda x, y: (tf.keras.layers.Rescaling(1./255)(x), y))

# --- Label conversion ---
def to_binary_labels(class_names, labels):
    healthy_indices = [i for i, name in enumerate(class_names) if 'healthy' in name.lower()]
    return [1 if label in healthy_indices else 0 for label in labels]

# --- Load models ---
cnn_model = tf.keras.models.load_model('/content/drive/MyDrive/PLANT MODELS COMPARISION/trained_plant_disease_model (3).keras')
vgg16_model = tf.keras.models.load_model('/content/drive/MyDrive/PLANT MODELS COMPARISION/trained_plant_disease_VGG16_model (1).keras')
mobilenet_model = tf.keras.models.load_model('/content/drive/MyDrive/PLANT MODELS COMPARISION/mobilenet_plant_disease_model.keras')

# --- Evaluation function ---
def evaluate_model(model, dataset, model_name, class_names):
    y_true, y_pred = [], []

    for images, labels in dataset:
        preds = model.predict(images)
        y_true.extend(to_binary_labels(class_names, np.argmax(labels.numpy(), axis=1)))
        y_pred.extend(to_binary_labels(class_names, np.argmax(preds, axis=1)))

    report = classification_report(y_true, y_pred, target_names=["Unhealthy", "Healthy"], output_dict=True)
    cm = confusion_matrix(y_true, y_pred)

    print(f"\n {model_name}")
    print(classification_report(y_true, y_pred, target_names=["Unhealthy", "Healthy"]))

    return {
        'Healthy': {
            'precision': report['Healthy']['precision'],
            'recall': report['Healthy']['recall'],
            'f1': report['Healthy']['f1-score'],
        },
        'Unhealthy': {
            'precision': report['Unhealthy']['precision'],
            'recall': report['Unhealthy']['recall'],
            'f1': report['Unhealthy']['f1-score'],
        }
    }

# --- Evaluate all models ---
metrics = {
    "CNN": evaluate_model(cnn_model, valid_dataset_cnn, "CNN (128x128)", class_names_cnn),
    "VGG16": evaluate_model(vgg16_model, valid_dataset_large, "VGG16 (224x224)", class_names_large),
    "MobileNet": evaluate_model(mobilenet_model, valid_dataset_large, "MobileNet (224x224)", class_names_large)
}

# --- Create single grouped bar chart ---
models = list(metrics.keys())
categories = ['precision', 'recall', 'f1']
labels = ['Healthy', 'Unhealthy']
bar_labels = [f"{label} {metric.capitalize()}" for metric in categories for label in labels]

x = np.arange(len(models))
width = 0.1

plt.figure(figsize=(14, 7))
colors = ['#00ba38', '#f8766d', '#00ba38', '#f8766d', '#00ba38', '#f8766d']  # Alternating green/red

# Loop through all metrics for healthy/unhealthy and plot
for i, (metric, label) in enumerate([(m, l) for m in categories for l in labels]):
    values = [metrics[model][label][metric] for model in models]
    plt.bar(x + (i - 2.5)*width, values, width, label=f"{label} {metric.capitalize()}", color=colors[i])
    for j in range(len(models)):
        plt.text(x[j] + (i - 2.5)*width, values[j] + 0.01, f'{values[j]:.2f}', ha='center', fontsize=8)

plt.xticks(x, models)
plt.ylim(0, 1.1)
plt.ylabel("Score")
plt.title("Comparison of Healthy & Unhealthy Metrics for CNN, VGG16, MobileNet")
plt.legend(loc="upper center", ncol=3)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Found 3770 files belonging to 37 classes.
# Found 3770 files belonging to 37 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
#
#  CNN (128x128)
#               precision    recall  f1-score   support
#
#    Unhealthy       0.97      0.93      0.95      2800
#      Healthy       0.81      0.92      0.86       970
#
#     accuracy                           0.92      3770
#    macro avg       0.89      0.92      0.90      3770
# weighted avg       0.93      0.92      0.92      3770
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 782ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
#
#  VGG16 (224x224)
#               precision    recall  f1-score   support
#
#    Unhealthy       0.99      0.89      0.94      2800
#      Healthy       0.75      0.97      0.85       970
#
#     accuracy                           0.91      3770
#    macro avg       0.87      0.93      0.89      3770
# weighted avg       0.93      0.91      0.91      3770
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#
#  MobileNet (224x224)
#               precision    recall  f1-score   support
#
#    Unhealthy       1.00      0.94      0.97      2800
#      Healthy       0.84      0.99      0.91       970
#
#     accuracy                           0.95      3770
#    macro avg       0.92      0.96      0.94      3770
# weighted avg       0.96      0.95      0.95      3770
